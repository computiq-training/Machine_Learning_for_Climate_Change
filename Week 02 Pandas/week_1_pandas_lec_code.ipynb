# %%
import pandas as pd

# %%
dataframe ={ "price":[12,23,42,94,94,12,123],
             "product code":['c1','c2','c3','c4','c4','c1','c7'],
             "amount":[10,2,13,4,4,10,10] }

# %%
df = pd.DataFrame(dataframe)

# %%
d = dataframe.loc[:,["price",'amount']]

# %%
d
# Out:
#    price  amount
# 0     12      10
# 1     23       2
# 2     42      13
# 3     94       4
# 4     94       4
# 5     12      10

# %%
d['amount'] = [1,2,3,4,5,6]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
d
# Out:
#    price  amount
# 0     12       1
# 1     23       2
# 2     42       3
# 3     94       4
# 4     94       5
# 5     12       6

# %%
df
# Out:
#    price product code  amount
# 0     12           c1      10
# 1     23           c2       2
# 2     42           c3      13
# 3     94           c4       4
# 4     94           c4       4
# 5     12           c1      10
# 6    123           c7      10

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# dtype: bool

# %%
df['amount'].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# Name: amount, dtype: bool

# %%
filt = df.duplicated(keep = 'last')

# %%
df.loc[~filt]
# Out:
#    price product code  amount
# 1     23           c2       2
# 2     42           c3      13
# 4     94           c4       4
# 5     12           c1      10
# 6    123           c7      10

# %%
! wget https://media.geeksforgeeks.org/wp-content/uploads/employees.csv
# Out:
# --2022-10-30 14:40:08--  https://media.geeksforgeeks.org/wp-content/uploads/employees.csv
# Resolving media.geeksforgeeks.org (media.geeksforgeeks.org)... 13.35.116.87, 13.35.116.119, 13.35.116.28, ...
# Connecting to media.geeksforgeeks.org (media.geeksforgeeks.org)|13.35.116.87|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59175 (58K) [text/csv]
# Saving to: ‘employees.csv’
#
# employees.csv       100%[===================>]  57.79K  --.-KB/s    in 0.02s
#
# 2022-10-30 14:40:09 (2.61 MB/s) - ‘employees.csv’ saved [59175/59175]

# %%
df_big = pd.read_csv("employees.csv")

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 478    Michael    Male   5/22/2011        10:42 AM   73354   18.357
# 859      Robin  Female   10/1/2012         2:44 AM   41808   19.239
# 936      Maria  Female   3/14/2003         5:23 PM   96250   10.056
# 666     Harold     NaN    2/4/2004        11:02 AM   79459    7.776
# 933      Doris  Female    7/5/1993         5:54 PM  141439    3.799
# ..         ...     ...         ...             ...     ...      ...
# 853    Mildred  Female    4/6/2007        10:06 PM  139284   11.390
# 855    Phillip     NaN  10/20/2003        11:09 AM   89700    2.277
# 864       Ryan    Male  11/16/2012         1:47 PM   57292    6.010
# 912        Joe    Male   12/8/1998        10:28 AM  126120    1.020
# 951        NaN  Female   9/14/2010         5:19 AM  143638    9.662
#
#     Senior Management                  Team
# 478             False  Business Development
# 859             False  Business Development
# ...

# %%
test = df.iloc[:250]

# %%
test
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 478    Michael    Male   5/22/2011        10:42 AM   73354   18.357
# 859      Robin  Female   10/1/2012         2:44 AM   41808   19.239
# 936      Maria  Female   3/14/2003         5:23 PM   96250   10.056
# 666     Harold     NaN    2/4/2004        11:02 AM   79459    7.776
# 933      Doris  Female    7/5/1993         5:54 PM  141439    3.799
# ..         ...     ...         ...             ...     ...      ...
# 778    Antonio    Male  12/28/2003         4:17 AM  137979    5.266
# 663     Andrea  Female   8/31/1989        11:10 PM  113760   12.866
# 804      Shawn    Male   3/17/2008         2:12 PM   39335   10.664
# 700      Frank    Male    3/2/2009         9:15 PM   78891    7.927
# 699        Amy     NaN   5/19/1984        11:47 AM  102839   10.385
#
#     Senior Management                  Team
# 478             False  Business Development
# 859             False  Business Development
# ...

# %%
df['Team'].value_counts()
# Out:
# Client Services         106
# Finance                 102
# Business Development    101
# Marketing                98
# Product                  95
# Sales                    94
# Engineering              92
# Human Resources          91
# Distribution             90
# Legal                    88
# Name: Team, dtype: int64

# %%
df.sample(n=250)['Team'].value_counts()
# Out:
# Client Services         30
# Engineering             30
# Business Development    27
# Finance                 27
# Distribution            25
# Sales                   25
# Product                 23
# Human Resources         22
# Legal                   18
# Marketing               15
# Name: Team, dtype: int64

# %%
df.sample(frac =.25)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 461     Jeremy    Male    8/9/2001         3:56 AM   43354   13.946
# 542     Amanda  Female    8/1/2004         1:32 PM   80803   14.077
# 16      Jeremy    Male   9/21/2010         5:56 AM   90370    7.369
# 488     Robert    Male   3/11/2007        11:20 AM  135882   19.944
# 405     Sharon  Female    3/9/2014         4:39 PM   91522    7.564
# ..         ...     ...         ...             ...     ...      ...
# 369       Mary  Female  10/18/2009         6:32 PM   87721   12.484
# 246       Fred     NaN   12/2/1984         2:03 PM   59937   12.045
# 393      Harry     NaN   12/5/1996         5:45 AM   46240    6.976
# 933      Doris  Female    7/5/1993         5:54 PM  141439    3.799
# 592     Justin    Male   5/24/1981        11:15 PM   78351   15.221
#
#     Senior Management                  Team
# 461             False             Marketing
# 542              True          Distribution
# ...

# %%
df
# Out:
#    price product code  amount
# 0     12           c1      10
# 1     23           c2       2
# 2     42           c3      13
# 3     94           c4       4
# 4     94           c4       4
# 5     12           c1      10
# 6    123           c7      10

# %%
df.sample(n = 2)
# Out:
#    price product code  amount
# 1     23           c2       2
# 2     42           c3      13

# %%
df.sample(n = 2 , random_state = 24 )
# Out:
#    price product code  amount
# 4     94           c4       4
# 6    123           c7      10

# %%
df.sort_values(by = ['Salary'])
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 576    Michael    Male  7/30/1993         5:35 PM   35013   14.879
# 238      Kevin    Male  3/25/1982         7:31 AM   35061    5.128
# 82      Steven    Male  3/30/1980         9:20 PM   35095    8.379
# 63     Matthew    Male   1/2/2013        10:33 PM   35203   18.040
# 650    Cynthia  Female   7/5/1986         1:24 AM   35381   11.749
# ..         ...     ...        ...             ...     ...      ...
# 160      Kathy  Female  3/18/2000         7:26 PM  149563   16.991
# 186        NaN  Female  2/23/2005         9:50 PM  149654    1.825
# 828    Cynthia  Female  7/12/2006         8:55 AM  149684    7.864
# 429       Rose  Female  5/28/2015         8:40 AM  149903    5.630
# 644  Katherine  Female  8/13/1996        12:21 AM  149908   18.912
#
#     Senior Management             Team
# 576             False          Product
# 238             False            Legal
# 82               True  Client Services
# ...

# %%
df.sort_values(by = (['First Name','Salary']), ascending = [False , True]).head(20)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 450     Willie    Male   8/22/2009         1:03 PM   55038   19.691
# 204     Willie    Male    6/6/2006         9:45 AM   55281    4.935
# 112     Willie    Male  11/27/2003         6:21 AM   64363    4.023
# 652     Willie    Male   12/5/2009         5:39 AM  141932    1.017
# 175     Willie    Male   2/17/1998         8:20 PM  146651    1.451
# 820    William    Male  11/18/1993        12:27 PM   54058    5.182
# 127    William    Male   9/29/2002         4:09 PM   66521    5.830
# 941    William    Male   6/26/1997         8:33 AM  104840   15.653
# 943      Wayne    Male    9/8/2006        11:09 AM   67471    2.728
# 448      Wayne    Male   1/30/1992         3:01 PM   81183   17.066
# 177      Wayne    Male    4/7/2012         8:00 AM  102652   14.085
# 637      Wayne    Male    9/2/2009         1:37 AM  126956   18.396
# 433      Wanda  Female   7/20/2008         1:44 PM   65362    7.132
# ...

# %%
df['Salary'].nlargest(10)
# Out:
# 644    149908
# 429    149903
# 828    149684
# 186    149654
# 160    149563
# 740    149456
# 793    149105
# 981    148985
# 800    148941
# 844    148857
# Name: Salary, dtype: int64

# %%
df.nsmallest(columns = 'Salary' ,n =10)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 576    Michael    Male   7/30/1993         5:35 PM   35013   14.879
# 238      Kevin    Male   3/25/1982         7:31 AM   35061    5.128
# 82      Steven    Male   3/30/1980         9:20 PM   35095    8.379
# 63     Matthew    Male    1/2/2013        10:33 PM   35203   18.040
# 650    Cynthia  Female    7/5/1986         1:24 AM   35381   11.749
# 900  Christina  Female   6/23/2002         3:18 PM   35477   18.178
# 530   Kathleen  Female   6/13/2014         9:16 AM   35575   14.595
# 762      Terry    Male  11/10/2004         4:33 AM   35633    3.947
# 964      Bruce    Male    5/7/1980         8:00 PM   35802   12.391
# 906    Frances  Female   5/16/2014         8:31 AM   35884   17.667
#
#     Senior Management             Team
# 576             False          Product
# 238             False            Legal
# 82               True  Client Services
# 63              False  Human Resources
# ...

# %%
df_big
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
d = {}

for index , team in  enumerate(df_big['Team'].unique()):
  d[team] = index

df_big['Team'].replace(d ,inplace = True)
df_big
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas       0    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas       0   3/31/1996         6:53 AM   61933    4.170
# 2        Maria       1   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry       0    3/4/2005         1:00 PM  138705    9.340
# 4        Larry       0   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry       2  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip       0   1/31/1984         6:30 AM   42392   19.675
# 997    Russell       0   5/20/2013        12:39 PM   96914    1.421
# 998      Larry       0   4/20/2013         4:45 PM   60500   11.985
# 999     Albert       0   5/15/2012         6:24 PM  129949   10.169
#
#      Senior Management  Team
# 0                    0     0
# 1                    0     1
# 2                    1     2
# 3                    0     2
# ...

# %%
df_big['Last Login Time']
# Out:
# 0      12:42 PM
# 1       6:53 AM
# 2      11:17 AM
# 3       1:00 PM
# 4       4:47 PM
#          ...
# 995     6:09 AM
# 996     6:30 AM
# 997    12:39 PM
# 998     4:45 PM
# 999     6:24 PM
# Name: Last Login Time, Length: 1000, dtype: object

# %%
import matplotlib.pyplot as plt
! wget https://www.w3schools.com/python/pandas/data.csv
# Out:
# --2022-11-01 15:12:57--  https://www.w3schools.com/python/pandas/data.csv
# Resolving www.w3schools.com (www.w3schools.com)... 192.229.173.207
# Connecting to www.w3schools.com (www.w3schools.com)|192.229.173.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2858 (2.8K) [application/octet-stream]
# Saving to: ‘data.csv.1’
#
# data.csv.1          100%[===================>]   2.79K  --.-KB/s    in 0s
#
# 2022-11-01 15:12:58 (76.1 MB/s) - ‘data.csv.1’ saved [2858/2858]

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
data['Calories'].plot(kind = 'hist')

# %%
data['Calories'].plot(kind = 'bar')

# %%
data.plot(kind = "scatter", x='Pulse' ,y= "Calories")

# %% [markdown]
# # review

# %%
data['Calories']
# Out:
# 0      409.1
# 1      479.0
# 2      340.0
# 3      282.4
# 4      406.0
#        ...
# 164    290.8
# 165    300.0
# 166    310.2
# 167    320.4
# 168    330.4
# Name: Calories, Length: 169, dtype: float64

# %%
n = pd.cut(data['Calories'],bins = 5)

# %%
n
# Out:
# 0       (48.49, 412.32]
# 1      (412.32, 774.34]
# 2       (48.49, 412.32]
# 3       (48.49, 412.32]
# 4       (48.49, 412.32]
#              ...
# 164     (48.49, 412.32]
# 165     (48.49, 412.32]
# 166     (48.49, 412.32]
# 167     (48.49, 412.32]
# 168     (48.49, 412.32]
# Name: Calories, Length: 169, dtype: category
# Categories (5, interval[float64, right]): [(48.49, 412.32] < (412.32, 774.34] < (774.34, 1136.36] <
#                                            (1136.36, 1498.38] < (1498.38, 1860.4]]

# %%
n.value_counts()
# Out:
# [106, 44, 7, 3, 2, 2]

# %%
 test = pd.DataFrame([[12 ,124],[40,20]])

# %%
test
# Out:
#     0    1
# 0  12  124
# 1  40   20

# %%
test.plot(kind = 'pie' ,subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe6b1639710>,
# ...
#       dtype=object)

# %%
n.value_counts().plot(kind= 'pie')

# %%
! wget https://info.stackoverflowsolutions.com/rs/719-EMH-566/images/stack-overflow-developer-survey-2022.zip
! unzip /content/stack-overflow-developer-survey-2022.zip

# %%
df = pd.read_csv('/content/survey_results_public.csv')
new_df = df[['LearnCode','EdLevel','YearsCodePro','Country','Age','LanguageHaveWorkedWith','CompTotal','Currency','CompFreq','ConvertedCompYearly']]

# %%
new_df.dropna(how ='any' , inplace =True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
new_df["ConvertedCompYearly"]
# Out:
# 2         40205.0
# 3        215232.0
# 10        60307.0
# 11       194400.0
# 12        65000.0
#            ...
# 73114     41058.0
# 73116    115000.0
# 73118     57720.0
# 73119     70000.0
# 73121     75384.0
# Name: ConvertedCompYearly, Length: 37716, dtype: float64

# %%
new_df["ConvertedCompYearly"].plot(kind = "pie")

# %%
new_df["ConvertedCompYearly"].nlargest(10)

# %%
new_df["ConvertedCompYearly"].median()

# %%
import numpy as np

# %%
np.mean([1, 2 , 3 ,100000])
# Out:
# 25001.5

# %%
d = {}

for index , team in  enumerate(new_df['Country'].unique()):
  d[team] = index

new_df['Country'].replace(d ,inplace = True)
new_df

# %%
new_df.plot(kind = "scatter" ,x ="ConvertedCompYearly", y= 'Country')

# %%
new_df

# %%
new_df.plot.bar()

# %%
new_df.plot(kind = 'hist')

# %%
new_df['ConvertedCompYearly'].plot(kind = 'hist',log = True , bins =20)

# %%
! wget https://github.com/CoreyMSchafer/code_snippets/raw/master/Python/Pandas/10-Datetime-Timeseries/ETH_1h.csv

# %%
x = "2012-02-01"

# %%
pd.to_datetime(x).day_name()
# Out:
# 'Wednesday'

# %%
data = pd.read_csv("ETH_1h.csv")

# %%
data['Date']
# Out:
# 0        2020-03-13 08-PM
# 1        2020-03-13 07-PM
# 2        2020-03-13 06-PM
# 3        2020-03-13 05-PM
# 4        2020-03-13 04-PM
#                ...
# 23669    2017-07-01 03-PM
# 23670    2017-07-01 02-PM
# 23671    2017-07-01 01-PM
# 23672    2017-07-01 12-PM
# 23673    2017-07-01 11-AM
# Name: Date, Length: 23674, dtype: object

# %%
data['Date'] = pd.to_datetime(data['Date'] , format = "%Y-%m-%d %I-%p")

# %%
filt = data['Date'] < '2019'
data.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 10509 2018-12-31 23:00:00  ETHUSD  130.62  131.36  130.20  130.53   869026.39
# 10510 2018-12-31 22:00:00  ETHUSD  129.97  131.00  129.07  130.62  1972726.62
# 10511 2018-12-31 21:00:00  ETHUSD  130.90  130.90  129.47  129.97  1079617.65
# 10512 2018-12-31 20:00:00  ETHUSD  131.17  131.58  130.36  130.90  1775465.69
# 10513 2018-12-31 19:00:00  ETHUSD  134.83  134.90  128.50  131.17  3380282.07
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [13165 rows x 7 columns]

# %%
data['Date'].max() - data['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
data['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
data['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
data.plot(x = "Date" , y ="High")
